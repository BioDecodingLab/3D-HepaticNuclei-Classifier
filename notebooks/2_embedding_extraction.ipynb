# %%
#!git clone https://github.com/AICONSlab/3DINO.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117, https://pypi.nvidia.com
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 3)) (0.24.0+cu126)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 6)) (0.1.5.post20221221)
# Requirement already satisfied: iopath in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 7)) (0.1.10)
# Requirement already satisfied: xformers in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 8)) (0.0.33.post1)
# Requirement already satisfied: submitit in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 9)) (1.5.4)
# Requirement already satisfied: cuml-cu11 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: monai==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: nibabel==5.1.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 13)) (5.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 14)) (1.6.1)
# Requirement already satisfied: torchio in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 15)) (0.21.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from monai==1.3.0->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 12)) (2.0.2)
# Requirement already satisfied: packaging>=17 in /usr/local/lib/python3.12/dist-packages (from nibabel==5.1.0->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 13)) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 5)) (0.15.2)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from fvcore->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 6)) (0.1.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from fvcore->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from fvcore->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 6)) (0.9.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from iopath->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: cuda-python<12.0a0,>=11.8.5 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (11.8.7)
# Requirement already satisfied: cudf-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: cupy-cuda11x>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (13.6.0)
# Requirement already satisfied: cuvs-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.1)
# Requirement already satisfied: dask-cuda==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: dask-cudf-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (1.5.3)
# Requirement already satisfied: libcuml-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: numba<0.62.0a0,>=0.59.1 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.60.0)
# Requirement already satisfied: nvidia-cublas-cu11 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (11.7.5.86)
# Requirement already satisfied: pylibraft-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: raft-dask-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: rapids-dask-dependency==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: rmm-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (1.16.3)
# Requirement already satisfied: treelite==4.4.1 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (4.4.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (6.2.6)
# Requirement already satisfied: cubinlinker-cu11 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.3.0.post3)
# Requirement already satisfied: libcudf-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: numba-cuda<0.12.0a0,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.11.0)
# Requirement already satisfied: nvtx>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.2.14)
# Requirement already satisfied: pandas<2.2.4dev0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2.2.2)
# Requirement already satisfied: ptxcompiler-cu11 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.8.1.post3)
# Requirement already satisfied: pyarrow<20.0.0a0,>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (18.1.0)
# Requirement already satisfied: pylibcudf-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (13.9.4)
# Requirement already satisfied: libcuvs-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuvs-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (8.3.1)
# Requirement already satisfied: pynvml<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (12.0.0)
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: libraft-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from libcuml-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: rapids-logger==0.1.* in /usr/local/lib/python3.12/dist-packages (from libcuml-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.1.19)
# Requirement already satisfied: distributed-ucxx-cu11==0.44.* in /usr/local/lib/python3.12/dist-packages (from raft-dask-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.44.0)
# Requirement already satisfied: ucx-py-cu11==0.44.* in /usr/local/lib/python3.12/dist-packages (from raft-dask-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.44.0)
# Requirement already satisfied: dask==2025.5.0 in /usr/local/lib/python3.12/dist-packages (from rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2025.5.0)
# Requirement already satisfied: distributed==2025.5.0 in /usr/local/lib/python3.12/dist-packages (from rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2025.5.0)
# Requirement already satisfied: librmm-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from rmm-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (6.5.1)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: ucxx-cu11==0.44.* in /usr/local/lib/python3.12/dist-packages (from distributed-ucxx-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.44.0)
# Requirement already satisfied: libkvikio-cu11==25.6.* in /usr/local/lib/python3.12/dist-packages (from libcudf-cu11==25.6.*->cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (25.6.0)
# Requirement already satisfied: libucx-cu11<1.19,>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from ucx-py-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (1.18.1)
# Requirement already satisfied: libucxx-cu11==0.44.* in /usr/local/lib/python3.12/dist-packages (from ucxx-cu11==0.44.*->distributed-ucxx-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.44.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 14)) (3.6.0)
# Requirement already satisfied: deprecated>=1.2 in /usr/local/lib/python3.12/dist-packages (from torchio->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.12/dist-packages (from torchio->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 15)) (0.8.2)
# Requirement already satisfied: humanize>=0.1 in /usr/local/lib/python3.12/dist-packages (from torchio->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 15)) (4.15.0)
# Requirement already satisfied: simpleitk!=2.0.*,!=2.1.1.1,>=1.3 in /usr/local/lib/python3.12/dist-packages (from torchio->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 15)) (2.5.3)
# Requirement already satisfied: typer>=0.1 in /usr/local/lib/python3.12/dist-packages (from torchio->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 15)) (0.21.1)
# Requirement already satisfied: cuda-bindings~=11.8.7 in /usr/local/lib/python3.12/dist-packages (from cuda-python<12.0a0,>=11.8.5->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (11.8.7)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda11x>=12.0.0->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.8.3)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2->torchio->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<0.62.0a0,>=0.59.1->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.43.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.1->torchio->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 15)) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (2025.3)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml<13.0.0a0,>=12.0.0->dask-cuda==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (12.575.51)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11->-r /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/requirements.txt (line 11)) (1.17.0)

# %%
import os, glob, random
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import tifffile

# %%
# Configuración de reproducibilidad
SEED = 42

def seed_everything(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(SEED)

# Rutas del conjunto de datos
TRAIN_DIR = "/content/drive/MyDrive/tesis/patches_train"
TEST_DIR  = "/content/drive/MyDrive/tesis/patches_test"

LABELS = [1,2,3,4,5]
TARGET_DHW0 = (80,80,80)  #Tamaño inicial del recorte (profundidad, alto, ancho)
TARGET_DHW  = (112,112,112) # Tamaño final de entrada al modelo

BATCH_SIZE = 8
NUM_WORKERS = 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3101544970.py in <cell line: 0>()
#       9     torch.backends.cudnn.benchmark = False
#      10
# ---> 11 seed_everything(SEED)
#      12
#      13 TRAIN_DIR = "/content/drive/MyDrive/tesis/patches_train"
#
# /tmp/ipython-input-3101544970.py in seed_everything(seed)
#       2
#       3 def seed_everything(seed=SEED):
# ----> 4     random.seed(seed)
#       5     np.random.seed(seed)
#       6     torch.manual_seed(seed)
#
# NameError: name 'random' is not defined

# %%
# Normaliza un volumen 3D a rango [-1, 1] usando cuantiles para reducir el efecto de outliers
def normalize_to_minus1_1(vol, p_low=0.0005, p_high=0.9995):
    vol = vol.astype(np.float32)
    lo = np.quantile(vol, p_low)
    hi = np.quantile(vol, p_high)
    vol = (vol - lo) / (hi - lo + 1e-8)
    vol = np.clip(vol * 2 - 1, -1, 1)
    return vol

# Realiza center-crop o padding simétrico para ajustar el volumen al tamaño objetivo (D, H, W)
def center_crop_or_pad_3d(vol, target_dhw):
    D,H,W = vol.shape
    tD,tH,tW = target_dhw
    pad_d = max(0, tD - D); pad_h = max(0, tH - H); pad_w = max(0, tW - W)

# Si el volumen es más pequeño que el objetivo, se rellena (padding) centrado
    if pad_d or pad_h or pad_w:
        vol = np.pad(
            vol,
            ((pad_d//2, pad_d - pad_d//2),
             (pad_h//2, pad_h - pad_h//2),
             (pad_w//2, pad_w - pad_w//2)),
            mode="constant",
            constant_values=float(vol.min())
        )
 # Si el volumen es más grande, se recorta (crop) centrado al tamaño objetivo
    D,H,W = vol.shape
    sD = (D - tD)//2
    sH = (H - tH)//2
    sW = (W - tW)//2
    return vol[sD:sD+tD, sH:sH+tH, sW:sW+tW]

# Aumento geométrico: flips aleatorios en ejes y rotación 2D en el plano (H, W)
def random_flip_rot(vol, rng: np.random.RandomState):
    if rng.rand() < 0.5: vol = vol[::-1, :, :]
    if rng.rand() < 0.5: vol = vol[:, ::-1, :]
    if rng.rand() < 0.5: vol = vol[:, :, ::-1]
    k = int(rng.randint(0, 4))
    vol = np.rot90(vol, k=k, axes=(1, 2))
    return vol.copy()

# Aumento de intensidad: escalado/shift de contraste-brillo y adición de ruido gaussiano
def intensity_aug(vol, rng: np.random.RandomState):
    if rng.rand() < 0.8:
        scale = 1.0 + rng.uniform(-0.2, 0.2)
        shift = rng.uniform(-0.1, 0.1)
        vol = np.clip(vol * scale + shift, -1, 1)
  # Ruido gaussiano leve (simula ruido de microscopía)
    if rng.rand() < 0.5:
        vol = np.clip(vol + rng.normal(0, 0.03, size=vol.shape).astype(np.float32), -1, 1)
    return vol

def augment_one(vol, rng: np.random.RandomState):
    vol = random_flip_rot(vol, rng)
    vol = intensity_aug(vol, rng)
    return vol

#aumentar el gaussion blur y noise, visualizar las aumentaciones de imagenes, verificar en fiji, hacer los embeddings sin aumetnar datos, 500, 3500 y 7000 , solo en el random forest primero

# %%
# Dataset para cargar volúmenes 3D en formato TIFF organizados por carpetas label_X
class Tif3DDatasetSingle(Dataset):
    def __init__(self, base_dir, labels, target_dhw0, target_dhw, do_aug=False, seed=SEED):
        self.items = []
        self.target_dhw0 = target_dhw0
        self.target_dhw = target_dhw
        self.do_aug = do_aug
        self.seed = seed

        for lv in labels:
            folder = os.path.join(base_dir, f"label_{lv}")
            files = sorted(glob.glob(os.path.join(folder, "*.tif")) + glob.glob(os.path.join(folder, "*.tiff")))
            self.items.extend([(f, lv) for f in files])

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        path, y = self.items[idx]
        vol = tifffile.imread(path).astype(np.float32)  # (Z,H,W)

        vol = normalize_to_minus1_1(vol)
        vol = center_crop_or_pad_3d(vol, self.target_dhw0)
        vol = np.resize(vol, self.target_dhw)

 #Aplica augmentation si está habilitado (determinístico por índice: seed + idx)
        if self.do_aug:
            rng = np.random.RandomState(self.seed + idx)
            vol = augment_one(vol, rng)

        x = torch.from_numpy(vol).unsqueeze(0)  # (1,D,H,W)
        return x, int(y), path

# Construye un índice balanceado por clase replicando (con reemplazo) hasta target_per_label
def build_augmented_index(items, labels, target_per_label, seed=SEED):
    rng = random.Random(seed)
    by_label = {lv: [] for lv in labels}
    for p, y in items:
        by_label[y].append((p, y))

    new_items = []
    for lv in labels:
        src = by_label[lv]
        if len(src) == 0:
            raise ValueError(f"No hay archivos en label_{lv}")
        for _ in range(target_per_label):
            new_items.append(rng.choice(src))
    rng.shuffle(new_items)
    return new_items

# %%
# Número objetivo de muestras por clase después del balanceo (sobremuestreo con augmentation)
TARGET_PER_LABEL = 7000

base_train = Tif3DDatasetSingle(TRAIN_DIR, LABELS, TARGET_DHW0, TARGET_DHW, do_aug=False, seed=SEED)
aug_items = build_augmented_index(base_train.items, LABELS, TARGET_PER_LABEL, seed=SEED)

train_aug = Tif3DDatasetSingle(TRAIN_DIR, LABELS, TARGET_DHW0, TARGET_DHW, do_aug=True, seed=SEED)
train_aug.items = aug_items

print("Train reales:", len(base_train), "| Train augmentado:", len(train_aug))
# Out:
# Train reales: 11959 | Train augmentado: 35000

# %%
# Establece el directorio actual en la ruta donde se encuentra el código fuente de 3DINO
cd /content/drive/MyDrive/tesis/3DINO-main/3DINO-main
# Out:
# /content/drive/MyDrive/tesis/3DINO-main/3DINO-main

# %%
# Importa funciones para cargar la configuración 3D y construir el modelo
from dinov2.eval.setup import build_model_for_eval
from dinov2.configs import load_and_merge_config_3d

config_file = "/content/drive/MyDrive/tesis/3DINO-main/3DINO-main/dinov2/configs/train/vit3d_highres"
pretrained_weights = "/content/drive/MyDrive/tesis/3dino_vit_weights.pth"

cfg = load_and_merge_config_3d(config_file)
model = build_model_for_eval(cfg, pretrained_weights)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()

print("Modelo listo en:", device)
# Out:
# /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/dinov2/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/dinov2/layers/attention.py:27: UserWarning: xFormers is available (Attention)
#   warnings.warn("xFormers is available (Attention)")
# /content/drive/MyDrive/tesis/3DINO-main/3DINO-main/dinov2/layers/block.py:33: UserWarning: xFormers is available (Block)
#   warnings.warn("xFormers is available (Block)")
# Modelo listo en: cuda

# %%
# Reproducibilidad en DataLoader
def seed_worker(worker_id):
    worker_seed = SEED + worker_id
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(SEED)

# Extracción de embeddings con 3DINO
def extract_embeddings(dataset, save_path):
    loader = DataLoader(
        dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        worker_init_fn=seed_worker,
        generator=g
    )

    all_emb, all_y, all_paths = [], [], []

    with torch.no_grad():
        for x, y, paths in loader:
            x = x.to(device, non_blocking=True)
            out = model(x)  # (B,1024)
            all_emb.append(out.cpu().numpy())
            all_y.append(np.array(y))
            all_paths.extend(list(paths))

    embeddings = np.concatenate(all_emb, axis=0)
    labels = np.concatenate(all_y, axis=0)

    np.savez_compressed(
        save_path,
        embeddings=embeddings,
        labels=labels,
        paths=np.array(all_paths, dtype=object)
    )

    print("Guardado:", save_path)
    print("Embeddings:", embeddings.shape, "| Labels:", labels.shape)
    return embeddings, labels

# %%
#Ruta para guardar los embeddings de train
save_train = "/content/drive/MyDrive/tesis/embeddings_3dino_TRAIN_aug10k_seed42_finn.npz"
train_embeddings, train_labels = extract_embeddings(train_aug, save_train)
# Out:
# Guardado: /content/drive/MyDrive/tesis/embeddings_3dino_TRAIN_aug10k_seed42_finn.npz
# Embeddings: (35000, 1024) | Labels: (35000,)

# %%
# dataset test SIN augmentation, solo tamaños 80->112
#Ruta para guardar los embeddings de test
test_ds = Tif3DDatasetSingle(TEST_DIR, LABELS, TARGET_DHW0, TARGET_DHW, do_aug=False, seed=SEED)
print("Test reales:", len(test_ds))

save_test = "/content/drive/MyDrive/tesis/embeddings_3dino_TEST_seed42_fin.npz"
test_embeddings, test_labels = extract_embeddings(test_ds, save_test)
# Out:
# Test reales: 2542
# Guardado: /content/drive/MyDrive/tesis/embeddings_3dino_TEST_seed42_fin.npz
# Embeddings: (2542, 1024) | Labels: (2542,)
